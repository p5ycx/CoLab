# %% [markdown]
# <a href="https://colab.research.google.com/github/p5ycx/CoLab/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json as js
jsnfile = open(r"")
jsnstr= jsnfile.read()
jsndat=jsnstr.load()
jsndat
jsnstr
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-a58dae692ae2> in <module>()
#       1 import json as js
# ----> 2 jsnfile = open(r"C:\Users\Akash\Downloads\exercise0_material (1)\exercise0_material\src_to_implement\data\Labels.json")
#       3 jsnstr= jsnfile.read()
#       4 jsndat=jsnstr.load()
#       5 jsndat
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Akash\\Downloads\\exercise0_material (1)\\exercise0_material\\src_to_implement\\data\\Labels.json'

# %% [markdown]
# # New Section
